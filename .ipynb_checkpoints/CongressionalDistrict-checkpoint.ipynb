# %%
import scipy.stats
import matplotlib.pyplot as plt
import copy
from sklearn import linear_model

import matplotlib
import matplotlib.patches as mpatches
from scipy import stats
from scipy.optimize import curve_fit
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
import seaborn as sns
import json
import statsmodels.api as sm

import pandas as pd
import numpy as np
import folium
from folium.features import DivIcon
import requests
from bs4 import BeautifulSoup
import re
import squarify
import os
# Out:
# /Users/manavdutta1/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
os.chdir("congressional-districts2018")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-742e76f3c24c> in <module>()
# ----> 1 os.chdir("congressional-districts2018")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'congressional-districts2018'

# %%
#throws exception
congressionalList = []
for dirname, dirnames, filenames in os.walk('.'):
      for subdirname in dirnames:
        if (subdirname != ".git" and subdirname != ".ipynb_checkpoints"):
           with open(os.getcwd() + "/" + subdirname + "/" + "shape.geojson", "r") as f:
                jsonFile = json.load(f)
                district = jsonFile["properties"]["District"]
                if (district.split(" ")[1] != "At-Large"):
                    district = district[0:len(district)-2]
                    jsonFile["properties"]["District"] = district
                print(district)
                congressionalList.append(jsonFile)
# Out:
# Alaska At-Large
# Alabama 1
# Alabama 2
# Alabama 3
# Alabama 4
# Alabama 5
# Alabama 6
# Alabama 7
# Arkansas 1
# Arkansas 2
# Arkansas 3
# Arkansas 4
# Arizona 1
# Arizona 2
# Arizona 3
# Arizona 4
# Arizona 5
# Arizona 6
# Arizona 7
# Arizona 8
# Arizona 9
# California 1
# California 10
# California 11
# California 12
# California 13
# California 14
# California 15
# California 16
# California 17
# California 18
# California 19
# California 2
# California 20
# California 21
# California 22
# California 23
# California 24
# California 25
# California 26
# California 27
# California 28
# California 29
# California 3
# California 30
# California 31
# California 32
# California 33
# California 34
# California 35
# California 36
# California 37
# California 38
# California 39
# California 4
# California 40
# California 41
# California 42
# California 43
# California 44
# California 45
# California 46
# California 47
# California 48
# California 49
# California 5
# California 50
# California 51
# California 52
# California 53
# California 6
# California 7
# California 8
# California 9
# Colorado 1
# Colorado 2
# Colorado 3
# Colorado 4
# Colorado 5
# Colorado 6
# Colorado 7
# Connecticut 1
# Connecticut 2
# Connecticut 3
# Connecticut 4
# Connecticut 5
# Delaware At-Large
# Florida 1
# Florida 10
# Florida 11
# Florida 12
# Florida 13
# Florida 14
# Florida 15
# Florida 16
# Florida 17
# Florida 18
# Florida 19
# Florida 2
# Florida 20
# Florida 21
# Florida 22
# Florida 23
# Florida 24
# Florida 25
# Florida 26
# Florida 27
# Florida 3
# Florida 4
# Florida 5
# Florida 6
# Florida 7
# Florida 8
# Florida 9
# Georgia 1
# Georgia 10
# Georgia 11
# Georgia 12
# Georgia 13
# Georgia 14
# Georgia 2
# Georgia 3
# Georgia 4
# Georgia 5
# Georgia 6
# Georgia 7
# Georgia 8
# Georgia 9
# Hawaii 1
# Hawaii 2
# Iowa 1
# Iowa 2
# Iowa 3
# Iowa 4
# Idaho 1
# Idaho 2
# Oklahoma 4
# Oklahoma 5
# Oregon 1
# Oregon 2
# Oregon 3
# Oregon 4
# Oregon 5
# Pennsylvania 1
# Pennsylvania 10
# Pennsylvania 11
# Pennsylvania 12
# Pennsylvania 13
# Pennsylvania 14
# Pennsylvania 15
# Pennsylvania 16
# Pennsylvania 17
# Pennsylvania 18
# Pennsylvania 2
# Pennsylvania 3
# Pennsylvania 4
# Pennsylvania 5
# Pennsylvania 6
# Pennsylvania 7
# Pennsylvania 8
# Pennsylvania 9
# Rhode Island 1
# Rhode Island 2
# South Carolina 1
# South Carolina 2
# South Carolina 3
# South Carolina 4
# South Carolina 5
# South Carolina 6
# South Carolina 7
# South Dakota At-Lar
# Tennessee 1
# Tennessee 2
# Tennessee 3
# Tennessee 4
# Tennessee 5
# Tennessee 6
# Tennessee 7
# Tennessee 8
# Tennessee 9
# Texas 1
# Texas 10
# Texas 11
# Texas 12
# Texas 13
# Texas 14
# Texas 15
# Texas 16
# Texas 17
# Texas 18
# Texas 19
# Texas 2
# Texas 20
# Texas 21
# Texas 22
# Texas 23
# Texas 24
# Texas 25
# Texas 26
# Texas 27
# Texas 28
# Texas 29
# Texas 3
# Texas 30
# Texas 31
# Texas 32
# Texas 33
# Texas 34
# Texas 35
# Texas 36
# Texas 4
# Texas 5
# Texas 6
# Texas 7
# Texas 8
# Texas 9
# Utah 1
# Utah 2
# Utah 3
# Utah 4
# Virginia 1
# Virginia 10
# Virginia 11
# Virginia 2
# Virginia 3
# Virginia 4
# Virginia 5
# Virginia 6
# Virginia 7
# Virginia 8
# Virginia 9
# Vermont At-Large
# Washington 1
# Washington 10
# Washington 2
# Washington 3
# Washington 4
# Washington 5
# Washington 6
# Washington 7
# Washington 8
# Washington 9
# Wisconsin 1
# Wisconsin 2
# Wisconsin 3
# Wisconsin 4
# Wisconsin 5
# Wisconsin 6
# Wisconsin 7
# Wisconsin 8
# West Virginia 1
# West Virginia 2
# West Virginia 3
# Wyoming At-Large
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6bc74f13589a> in <module>()
#       4       for subdirname in dirnames:
#       5         if (subdirname != ".git" and subdirname != ".ipynb_checkpoints"):
# ----> 6            with open(os.getcwd() + "/" + subdirname + "/" + "shape.geojson", "r") as f:
#       7                 jsonFile = json.load(f)
#       8                 district = jsonFile["properties"]["District"]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/manavdutta1/Downloads/congressional-districts2018/branches/shape.geojson'

# %%
jsonDict = {"type": "FeatureCollection", "features": congressionalList}
with open('geocounties.json', 'w') as outfile:  
    json.dump(jsonDict, outfile)

# %%
cookData = pd.read_csv('cookPVI.csv')
for i in range(len(cookData)):
    pvi = cookData.iloc[i]["PVI"]
    if (pvi[0:2] == "D+"):
       value = int(pvi.split("+")[1])     
       cookData.at[i, "PVI"] = value
    elif (pvi == "EVEN"):
       cookData.at[i, "PVI"] = 0
    else:
        value = -1 * int(pvi.split("+")[1])
        cookData.at[i, "PVI"] = value

# %%
for i in range(len(cookData)):
    district = cookData.iloc[i]["District"]
    stateArr = district.split(" ")
    if (stateArr[1] == "AL"):
        stateArr[1] = "At-Large"
    cookData.at[i, "District"] = " ".join(stateArr)

# %%
print(cookData)
# Out:
#              District  PVI
# 0           Alabama 1  -15
# 1           Alabama 2  -16
# 2           Alabama 3  -16
# 3           Alabama 4  -30
# 4           Alabama 5  -18
# 5           Alabama 6  -26
# 6           Alabama 7   20
# 7     Alaska At-Large   -9
# 8           Arizona 1   -2
# 9           Arizona 2   -1
# 10          Arizona 3   13
# 11          Arizona 4  -21
# 12          Arizona 5  -15
# 13          Arizona 6   -9
# 14          Arizona 7   23
# 15          Arizona 8  -13
# 16          Arizona 9    4
# 17         Arkansas 1  -17
# 18         Arkansas 2   -7
# 19         Arkansas 3  -19
# 20         Arkansas 4  -17
# 21       California 1  -11
# 22       California 2   22
# 23       California 3    5
# 24       California 4  -10
# 25       California 5   21
# 26       California 6   21
# 27       California 7    3
# 28       California 8   -9
# 29       California 9    8
# ..                ...  ...
# 405        Virginia 4   10
# 406        Virginia 5   -6
# 407        Virginia 6  -13
# 408        Virginia 7   -6
# 409        Virginia 8   21
# 410        Virginia 9  -19
# 411       Virginia 10    1
# 412       Virginia 11   15
# 413      Washington 1    6
# 414      Washington 2   10
# 415      Washington 3   -4
# 416      Washington 4  -13
# 417      Washington 5   -8
# 418      Washington 6    6
# 419      Washington 7   33
# 420      Washington 8    0
# 421      Washington 9   21
# 422     Washington 10    5
# 423   West Virginia 1  -19
# 424   West Virginia 2  -17
# 425   West Virginia 3  -23
# 426       Wisconsin 1   -5
# 427       Wisconsin 2   18
# 428       Wisconsin 3    0
# 429       Wisconsin 4   25
# 430       Wisconsin 5  -13
# 431       Wisconsin 6   -8
# 432       Wisconsin 7   -8
# 433       Wisconsin 8   -7
# 434  Wyoming At-Large  -25
#
# [435 rows x 2 columns]

# %%
geo = r'geocounties.json'
def constructMap(partisan_lean, incumbency_value):
    disposableCookData = cookData.copy(deep=True)
    demCount = 0
    for i in range(len(disposableCookData)):
        pvi = disposableCookData.iloc[i]["PVI"]
        disposableCookData.at[i, "PVI"] = pvi + partisan_lean + incumbency_value
        if (disposableCookData.iloc[i]["PVI"] > 0):
            demCount += 1
    foliumMap = folium.Map(location=[48, -102], zoom_start=3) 
    foliumMap.choropleth(geo_data=geo, data=disposableCookData,
             columns=["District",'PVI'],
             key_on='feature.properties.District', threshold_scale=[-10, -5, 0, 5, 10],
             fill_color='RdBu', fill_opacity=0.7, line_opacity=0.2,
             legend_name="PVI")
    return foliumMap

# %%
theMap = constructMap(7.5, 3)
theMap.save("map.html")

# %%
slider = widgets.IntSlider(value=0, min=-20, max=20, step=1)
incumbencySlider = widgets.IntSlider(value=0, min=-10, max=10, step=1)
interact(constructMap, partisan_lean=slider, incumbency_value=incumbencySlider)
None
# Out:
# interactive(children=(IntSlider(value=0, description='partisan_lean', max=20, min=-20), IntSlider(value=0, des…
